# %%
from dotenv import load_dotenv

# %%
import os

# %%
load_dotenv()
# Out:
# True

# %%
from openai import OpenAI

# %%
client = OpenAI(api_key = os.getenv("OPENAI_API_KEY"))

# %%
test = client.responses.create(
    model = "gpt-3.5-turbo",
    messages = [
        {"role": "system", "content": ''' 

        
        
        '''}
    ]
)

print(test.output)
# Out:
# [ResponseOutputMessage(id='msg_08201ca0ea210c1800691148cb3b5081a39614212c1c9433e5', content=[ResponseOutputText(annotations=[], text='Hello, my name is Rakshit Lodha. I am a software engineer by profession and I specialize in developing web applications. I have a passion for problem-solving and creating innovative solutions to complex challenges. In my free time, I enjoy exploring new technologies and learning new skills to enhance my expertise. I am dedicated to delivering high-quality work and exceeding expectations in every project I undertake.', type='output_text', logprobs=[])], role='assistant', status='completed', type='message')]
